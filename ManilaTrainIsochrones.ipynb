# %%
# !pip install openrouteservice geopandas mapclassify folium==0.14.0 pyogrio

# %%
import openrouteservice

client = openrouteservice.Client(key='') # Fill in api key here

# %%
import json
with open("mrt.geojson") as f:
    mrt_geojson = json.load(f)

with open("lrt1.geojson") as f:
    lrt1_geojson = json.load(f)
  
with open("lrt2.geojson") as f:
    lrt2_geojson = json.load(f)

# %%
import geopandas as gpd
import pandas as pd
import pyogrio

# https://openrouteservice.org/restrictions/
# https://openrouteservice.org/dev/#/api-docs/v2/isochrones/{profile}/post 
time = [3*60, 6*60, 9*60, 12*60, 15*60] # max of 10 intervals
profile = 'foot-walking'
max_query_size = 5 # max 5 for isochrones
def isochrones(geojson):
    locations = [ feature['geometry']['coordinates'] for feature in geojson['features']]
    gdfs = []
    for i in range(0, len(locations), max_query_size):
        chunk = locations[i:i+max_query_size]
        results = openrouteservice.isochrones.isochrones(client, locations=chunk, profile=profile,range=time)
        gdf = gpd.GeoDataFrame.from_features(results["features"])
        gdfs.append(gdf)
    return pd.concat(gdfs)

# %%
mrt_gdf = isochrones(mrt_geojson)
pyogrio.write_dataframe(mrt_gdf, "mrt_isochrones.geojson", driver="GeoJSON")

# %%
lrt1_gdf = isochrones(lrt1_geojson)
pyogrio.write_dataframe(lrt1_gdf, "lrt1_isochrones.geojson", driver="GeoJSON")

# %%
lrt2_gdf = isochrones(lrt2_geojson)
pyogrio.write_dataframe(lrt2_gdf, "lrt2_isochrones.geojson", driver="GeoJSON")

# %%
all = pd.concat([mrt_gdf, lrt1_gdf, lrt2_gdf])

# %%
all
# Out:
#                                              geometry  group_index  value  \
# 0   POLYGON ((121.03081 14.65373, 121.03135 14.652...            0  180.0
# 1   POLYGON ((121.02939 14.65535, 121.02958 14.654...            0  360.0
# 2   POLYGON ((121.02727 14.65584, 121.02906 14.652...            0  540.0
# 3   POLYGON ((121.02501 14.65633, 121.02581 14.655...            0  720.0
# 4   POLYGON ((121.02282 14.65692, 121.02358 14.655...            0  900.0
# ..                                                ...          ...    ...
# 10  POLYGON ((120.98084 14.60378, 120.98176 14.602...            2  180.0
# 11  POLYGON ((120.97870 14.60462, 120.97908 14.603...            2  360.0
# 12  POLYGON ((120.97665 14.60525, 120.97731 14.603...            2  540.0
# 13  POLYGON ((120.97449 14.60607, 120.97515 14.604...            2  720.0
# 14  POLYGON ((120.97208 14.60641, 120.97216 14.606...            2  900.0
#
#                                       center
# 0   [121.03226031541993, 14.652202085132709]
# 1   [121.03226031541993, 14.652202085132709]
# 2   [121.03226031541993, 14.652202085132709]
# 3   [121.03226031541993, 14.652202085132709]
# 4   [121.03226031541993, 14.652202085132709]
# ..                                       ...
# 10   [120.98336495641382, 14.60358554379944]
# 11   [120.98336495641382, 14.60358554379944]
# 12   [120.98336495641382, 14.60358554379944]
# 13   [120.98336495641382, 14.60358554379944]
# 14   [120.98336495641382, 14.60358554379944]
#
# [230 rows x 4 columns]

# %%
all.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afd66d9fef88f7b2744202ea9ef1f2dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afd66d9fef88f7b2744202ea9ef1f2dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afd66d9fef88f7b2744202ea9ef1f2dd = L.map(
#                 &quot;map_afd66d9fef88f7b2744202ea9ef1f2dd&quot;,
#                 {
#                     center: [14.595041, 121.0516605],
#                     crs: L.CRS.Simple,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_afd66d9fef88f7b2744202ea9ef1f2dd);
#
#
#
#
#
#             map_afd66d9fef88f7b2744202ea9ef1f2dd.fitBounds(
#                 [[14.5235, 120.970915], [14.666582, 121.132406]],
#                 {}
#             );
#
#
#         function geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_7ebdb7bdaea81d2495cda35ef9a964bc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7ebdb7bdaea81d2495cda35ef9a964bc = L.geoJson(null, {
#                 onEachFeature: geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_onEachFeature,
#
#                 style: geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_styler,
#                 pointToLayer: geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_pointToLayer
#         });
#
#         function geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_add (data) {
#             geo_json_7ebdb7bdaea81d2495cda35ef9a964bc
#                 .addData(data)
#                 .addTo(map_afd66d9fef88f7b2744202ea9ef1f2dd);
#         }
#             geo_json_7ebdb7bdaea81d2495cda35ef9a964bc_add({&quot;bbox&quot;: [120.970915, 14.5235, 121.132406, 14.666582], &quot;features&quot;: [{&quot;bbox&quot;: [121.030809, 14.650739, 121.033652, 14.654217], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[121.030809, 14.653733], [121.031346, 14.652922], [121.031883, 14.652112], [121.033094, 14.650824], [121.03332, 14.650739], [121.033625, 14.650931], [121.033652, 14.650971], [121.033352, 14.651441], [121.032709, 14.652486], [121.032217, 14.653222], [121.031562, 14.654217], [121.031258, 14.654024], [121.031109, 14.653931], [121.030809, 14.653733]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;center&quot;: [121.03226031541993, 14.652202085132709], &quot;group_index&quot;: 0, &quot;value&quot;: 180.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [121.029387, 14.648871, 121.034968, 14.655604], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[121.029387, 14.655351], [121.029581, 14.654372], [121.031883, 14.652112], [121.03424, 14.649044], [121.034411, 14.648871], [121.034696, 14.648899], [121.034968, 14.649135], [121.0349, 14.651964], [121.034835, 14.652105], [121.034746, 14.652247], [121.03146, 14.65541], [121.030844, 14.655569], [121.030484, 14.655578], [121.029643, 14.655604], [121.029387, 14.655351]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;center&quot;: [121.03226031541993, 14.652202085132709], &quot;

# %%
# Merge geometry with same value/time interval
merged_rows = []
for time in all.value.unique():
    subset = all[all.value == time]
    merged_rows.append({'geometry':subset.geometry.unary_union, 'time': time})

merged_gdf = gpd.GeoDataFrame(merged_rows)

# %%
# Clean geometries by removing area that are contained in smaller intervals. This allows styling to be 
last_geom= None
geoms_clean = []
for idx, row in merged_gdf.iterrows():
    if idx != 0:
        diff = row.geometry.difference(last_geom)
        geoms_clean.append({'geometry': diff, 'time':row.time })
    else:
        geoms_clean.append({'geometry': row.geometry, 'time':row.time})
    last_geom = row.geometry
clean_gdf = gpd.GeoDataFrame(geoms_clean)

# %%
clean_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2351d4a9d0fb7ed34f085c699cacea1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2351d4a9d0fb7ed34f085c699cacea1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2351d4a9d0fb7ed34f085c699cacea1b = L.map(
#                 &quot;map_2351d4a9d0fb7ed34f085c699cacea1b&quot;,
#                 {
#                     center: [14.595041, 121.0516605],
#                     crs: L.CRS.Simple,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2351d4a9d0fb7ed34f085c699cacea1b);
#
#
#
#
#
#             map_2351d4a9d0fb7ed34f085c699cacea1b.fitBounds(
#                 [[14.5235, 120.970915], [14.666582, 121.132406]],
#                 {}
#             );
#
#
#         function geo_json_3ad97dcbcb969b20cd607546b726fba3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3ad97dcbcb969b20cd607546b726fba3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3ad97dcbcb969b20cd607546b726fba3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3ad97dcbcb969b20cd607546b726fba3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3ad97dcbcb969b20cd607546b726fba3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3ad97dcbcb969b20cd607546b726fba3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3ad97dcbcb969b20cd607546b726fba3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3ad97dcbcb969b20cd607546b726fba3 = L.geoJson(null, {
#                 onEachFeature: geo_json_3ad97dcbcb969b20cd607546b726fba3_onEachFeature,
#
#                 style: geo_json_3ad97dcbcb969b20cd607546b726fba3_styler,
#                 pointToLayer: geo_json_3ad97dcbcb969b20cd607546b726fba3_pointToLayer
#         });
#
#         function geo_json_3ad97dcbcb969b20cd607546b726fba3_add (data) {
#             geo_json_3ad97dcbcb969b20cd607546b726fba3
#                 .addData(data)
#                 .addTo(map_2351d4a9d0fb7ed34f085c699cacea1b);
#         }
#             geo_json_3ad97dcbcb969b20cd607546b726fba3_add({&quot;bbox&quot;: [120.970915, 14.5235, 121.132406, 14.666582], &quot;features&quot;: [{&quot;bbox&quot;: [120.979264, 14.532385, 121.123754, 14.659362], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[120.999294, 14.554939], [120.999379, 14.554589], [120.999388, 14.554327], [120.999085, 14.553751], [120.997871, 14.551941], [120.997521, 14.551859], [120.997423, 14.551914], [120.994978, 14.553257], [120.994901, 14.553519], [120.994848, 14.553875], [120.99582, 14.555424], [120.996658, 14.556427], [120.996709, 14.556443], [120.998635, 14.555314], [120.999294, 14.554939]]], [[[120.996366, 14.562966], [120.996335, 14.56215], [120.995611, 14.561377], [120.995261, 14.561292], [120.994393, 14.561584], [120.994135, 14.561763], [120.99354, 14.565551], [120.993866, 14.565704], [120.995426, 14.565067], [120.995577, 14.56474], [120.996219, 14.563289], [120.996366, 14.562966]]], [[[120.992981, 14.570457], [120.992809, 14.567984], [120.992483, 14.56783], [120.990792, 14.568963], [120.990513, 14.569191], [120.990307, 14.569943], [120.990259, 14.5703], [120.990378, 14.572126], [120.990692, 14.572304], [120.992404, 14.571725], [120.99268, 14.571495], [120.992981, 14.570457]]], [[[120.989972, 14.576995], [120.990112, 14.576663], [120.989751, 14.57566], [120.989392, 14.574628], [120.989077, 14.574455], [120.988966, 14.574485], [120.986644, 14.575183], [120.986498, 14.575512], [120.986563, 14.577686], [120.986821, 14.578379], [120.987131, 14.578563], [12

# %%
clean_gdf
# Out:
#                                             geometry   time
# 0  MULTIPOLYGON (((120.99929 14.55494, 120.99938 ...  180.0
# 1  MULTIPOLYGON (((121.00036 14.55644, 121.00099 ...  360.0
# 2  MULTIPOLYGON (((121.00246 14.55218, 121.00198 ...  540.0
# 3  MULTIPOLYGON (((121.00532 14.55221, 121.00528 ...  720.0
# 4  MULTIPOLYGON (((121.04435 14.55551, 121.04431 ...  900.0

# %%
pyogrio.write_dataframe(clean_gdf, "final.geojson", driver="GeoJSON")
